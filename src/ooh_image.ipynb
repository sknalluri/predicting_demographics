# %% [markdown]
# This notebook reads am xml file comntaining occupation titles and four image URLS to creates an HTML dataframe and webpage with four rendered images of each job description contained in the Bureau of Labor Statistics (BLS) Occupational Outlook Handbook (OOH). The images are those taken from thumbnails shown at the occupation group level (1) and from those shown in each of the following tabs at the individual occupation level (3): `What They Do`, `Work Environment`, `How to Become One`.

# %%
import pandas as pd
import numpy as np
from IPython.core.display import HTML

# %%
# Read images into df
ooh_images = pd.read_csv(r"OOH_Image_Data.txt", sep='|')
ooh_images
# Out:
#                                                  Title  \
# 0                             Accountants and Auditors
# 1                                               Actors
# 2                                            Actuaries
# 3      Administrative Services and Facilities Managers
# 4    Adult Basic and Secondary Education and ESL Te...
# ..                                                 ...
# 319  Wholesale and Manufacturing Sales Representatives
# 320                           Wind Turbine Technicians
# 321                                        Woodworkers
# 322                                Writers and Authors
# 323                 Zoologists and Wildlife Biologists
#
#                                       Image_1  \
# 0    https://www.bls.gov/ooh/images/15122.jpg
# 1    https://www.bls.gov/ooh/images/15292.jpg
# 2    https://www.bls.gov/ooh/images/15610.jpg
# 3    https://www.bls.gov/ooh/images/15556.jpg
# 4    https://www.bls.gov/ooh/images/15262.jpg
# ...

# %%
from IPython.core.display import HTML

# %%
# Function to convert links to html tags
def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

# %%
# Rendering df as HTML table
ooh_images.to_html(escape=False, 
                   formatters=dict(Image_1=path_to_image_html,
                                   Image_2=path_to_image_html,
                                   Image_3=path_to_image_html,
                                   Image_4=path_to_image_html
                                  )
                  )
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Title</th>\n      <th>Image_1</th>\n      <th>Image_2</th>\n      <th>Image_3</th>\n      <th>Image_4</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Accountants and Auditors</td>\n      <td><img src="https://www.bls.gov/ooh/images/15122.jpg" width="60" ></td>\n      <td><img src="https://www.bls.gov/ooh/images/1740.jpg" width="60" ></td>\n      <td><img src="https://www.bls.gov/ooh/images/1741.jpg" width="60" ></td>\n      <td><img src="https://www.bls.gov/ooh/images/1743.jpg" width="60" ></td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Actors</td>\n      <td><img src="https://www.bls.gov/ooh/images/15292.jpg" width="60" ></td>\n      <td><img src="https://www.bls.gov/ooh/images/2284.jpg" width="60" ></td>\n      <td><img src="https://www.bls.gov/ooh/images/2286.jpg" width="60" ></td>\n      <td><img src="https://www.bls.gov/ooh/image
# ...

# %%
# Rendering images in df using HTML method
HTML(ooh_images.to_html(escape=False,
                        formatters=dict(Image_1=path_to_image_html,
                                        Image_2=path_to_image_html,
                                        Image_3=path_to_image_html,
                                        Image_4=path_to_image_html
                                       )
                       )
    )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Title</th>
#       <th>Image_1</th>
#       <th>Image_2</th>
#       <th>Image_3</th>
#       <th>Image_4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Accountants and Auditors</td>
#       <td><img src="https://www.bls.gov/ooh/images/15122.jpg" width="60" ></td>
#       <td><img src="https://www.bls.gov/ooh/images/1740.jpg" width="60" ></td>
#       <td><img src="https://www.bls.gov/ooh/images/1741.jpg" width="60" ></td>
#       <td><img src="https://www.bls.gov/ooh/images/1743.jpg" width="60" ></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Actors</td>
#       <td><img src="https://www.bls.gov/ooh/images/15292.jpg" width="60" ></td>
#       <td><img src="https://www.bls.gov/ooh/images/2284.jpg" width="60" ></td>
#       <td><img src="https://www.bls.gov/ooh/images/2286.jpg" width="60" ></td>
# ...

# %%
# Saving the dataframe as a webpage
ooh_images.to_html("ooh_images.html",
                   escape=False, 
                   formatters=dict(Image_1=path_to_image_html,
                                   Image_2=path_to_image_html,
                                   Image_3=path_to_image_html,
                                   Image_4=path_to_image_html
                                  )
                  )
